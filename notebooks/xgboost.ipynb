# %%
from utils import retrieve_latest_train_test, run_grid_search_cv, save_results_and_session, load_latest_session
from gscv_configs import gscv_cfg_xgb

# This notebook applies XGBClassifier
name = gscv_cfg_xgb.name

# %%
# load data
train, test = retrieve_latest_train_test()

# run grid search cv
_gscv, pred = run_grid_search_cv(
    gscv_dct=gscv_cfg_xgb,
    X_train=train.drop(["Survived"], axis=1),
    y_train=train["Survived"],
    X_test=test.drop(["Survived"], axis=1),
    )

# save results
save_results_and_session(name, _gscv.__dict__)
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   1.7s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.6s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.7s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.5s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.3s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.3s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.3s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.4s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.3s
# [CV] END colsample_bylevel=0.2, colsample_bytree=0.9, gamma=0, learning_rate=0.7, max_depth=3, n_estimators=100, subsample=0.6; total time=   0.3s
# WARNING:root:Results have been saved to '../gscv/xgboost/2022-11-28T15:39:39.json'
# WARNING:root:Session has been saved to '/sessions/xgboost/2022-11-28T15:39:39.json'
