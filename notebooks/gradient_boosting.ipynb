# %%
from sklearn.model_selection import train_test_split
from utils import retrieve_latest_dataset, get_X_and_y, run_grid_search_cv, save_results_and_session, load_latest_session
from gscv_configs import gscv_cfg_gb

# This notebook applies GradientBoostingClassifier
name = gscv_cfg_gb.name

# %%
# load data
df = retrieve_latest_dataset()
X, y = get_X_and_y(df)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42, shuffle=True)

# run grid search cv
_gscv = run_grid_search_cv(gscv_dct=gscv_cfg_gb, X_train=X_train, y_train=y_train).__dict__

# save results
save_results_and_session(name, _gscv)
# Out:
# Fitting 10 folds for each of 54 candidates, totalling 540 fits
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# ...

# %%
load_latest_session(name)
# Out:
# WARNING:root:Session has been loaded from '/sessions/gradient_boosting/2022-11-16T09:48:53.pkl'
