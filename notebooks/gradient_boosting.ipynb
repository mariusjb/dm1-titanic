# %%
from utils import retrieve_latest_train_test, run_grid_search_cv, save_results_and_session, load_latest_session
from gscv_configs import gscv_cfg_gb

# This notebook applies GradientBoostingClassifier
name = gscv_cfg_gb.name

# %%
# load data
train, test = retrieve_latest_train_test()

# run grid search cv
_gscv = run_grid_search_cv(
    gscv_dct=gscv_cfg_gb,
    X_train=train.drop(["Survived"], axis=1),
    y_train=train["Survived"]
    ).__dict__

# save results
save_results_and_session(name, _gscv)
# Out:
# Fitting 10 folds for each of 54 candidates, totalling 540 fits
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.001, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.01, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=1, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=sqrt, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=50; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=3, max_features=log2, n_estimators=100; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.2s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=sqrt, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=10; total time=   0.0s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=50; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s
# WARNING:root:Results have been saved to '../gscv/gradient_boosting/2022-11-23T12:18:38.json'
# WARNING:root:Session has been saved to '/sessions/gradient_boosting/2022-11-23T12:18:38.json'
# [CV] END learning_rate=0.1, max_depth=7, max_features=log2, n_estimators=100; total time=   0.1s

# %%
# load_latest_session(name)
